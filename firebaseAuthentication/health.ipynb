# %%
import pandas as pd

cema = pd.read_csv("C:/Users/USER/Downloads/cema_internship_task_2023.csv")
cema
# Out:
#       period                  county  Total Dewormed  Acute Malnutrition  \
# 0     Jan-23          Baringo County            3659                 8.0
# 1     Jan-23            Bomet County            1580                 NaN
# 2     Jan-23          Bungoma County            6590                24.0
# 3     Jan-23            Busia County            7564                 NaN
# 4     Jan-23  Elgeyo Marakwet County            1407                 NaN
# ...      ...                     ...             ...                 ...
# 1405  Dec-21            Kitui County           29802                 1.0
# 1406  Dec-21           Kisumu County            5431                26.0
# 1407  Dec-21            Kisii County            2040                 NaN
# 1408  Dec-21            Wajir County           13522               432.0
# 1409  Dec-21       West Pokot County            6970                22.0
#
#       stunted 6-23 months  stunted 0-<6 months  stunted 24-59 months  \
# 0                   471.0                 34.0                 380.0
# 1                     1.0                  3.0                   NaN
# 2                    98.0                154.0                  23.0
# 3                   396.0                143.0                 111.0
# 4                    92.0                 71.0                   5.0
# ...                   ...                  ...                   ...
# 1405                226.0                119.0                 115.0
# 1406                101.0                 60.0                  72.0
# 1407                 40.0                 42.0                   7.0
# 1408                 66.0                  1.0                 206.0
# 1409                  5.0                 57.0                  12.0
#
#       diarrhoea cases  Underweight 0-<6 months  Underweight 6-23 months  \
# 0                2620                       85                    739.0
# 1                1984                       41                     86.0
# 2                4576                      231                    315.0
# 3                2239                      251                    608.0
# 4                2739                       57                    104.0
# ...               ...                      ...                      ...
# 1405             2214                      182                    744.0
# 1406             3494                      190                    440.0
# 1407             2471                       71                     97.0
# 1408             3922                       83                    484.0
# 1409             2477                       38                     87.0
#
#       Underweight 24-59 Months
# 0                        731.0
# 1                         16.0
# 2                        120.0
# 3                        125.0
# 4                         21.0
# ...                        ...
# 1405                     245.0
# 1406                     106.0
# 1407                      41.0
# 1408                     656.0
# 1409                      28.0
#
# [1410 rows x 11 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
cema = pd.read_csv("C:/Users/USER/Downloads/cema_internship_task_2023.csv")

# Sort values by period
cema.sort_values(by='period', inplace=True)

# Plot Total Dewormed over period
plt.figure(figsize=(10, 6))
plt.plot(cema['period'], cema['Total Dewormed'], marker='o', linestyle='-')
plt.title('Total Dewormed Over Period')
plt.xlabel('Period')
plt.ylabel('Total Dewormed')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()
plt.show()
